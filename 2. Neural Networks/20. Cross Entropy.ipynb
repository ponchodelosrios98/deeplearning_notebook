# %% [markdown]
# # Cross Entropy
#
# So we're getting somewhere, there's definitely a connection between probabilities and error functions, and it's called Cross-Entropy. This concept is tremendously popular in many fields, including Machine Learning. Let's dive more into the formula, and actually code it!
#
# To calculate maximium likelihood, products became a problem when we are talking about a lot of data, that's why we will use negative Logs
#
#
# ![cross_entropy1.png](attachment:cross_entropy1.png)
#
#
# ![cross_entropyGraph.png](attachment:cross_entropyGraph.png)

# %% [markdown]
# ## Cross Entropy Example
#
# ![cross_EntropyExample.png](attachment:cross_EntropyExample.png)

# %%
import numpy as np

def cross_entropy(Y, P):
    Y = np.float_(Y)
    P = np.float_(P)
    return -np.sum(Y * np.log(P) + (1 - Y) * np.log(1 - P))

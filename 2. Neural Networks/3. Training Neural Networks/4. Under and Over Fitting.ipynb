# %% [markdown]
# ## Underfitting and Overfitting
#
# When developing ANN, the train network can create a high bias on the weights, which will cause overfitting in the predictions
#
# ![fitting_architecture.png](attachment:fitting_architecture.png)
#
# ## The number of epochs
#
# The number of epochs alter the weights, depending on the architecture and the test results we need to verify how many epochs are just right to train the dataset
#
# ![stopping.png](attachment:stopping.png)
#
# ## Early Stopping
#
# As we see in the next image, the number of epochs does not equal the asserts of the model in the test dataset, there's a method called early stopping which means detecting at what number of epochs gave better test results
#
#
# ![graphed_epochs.png](attachment:graphed_epochs.png)
#
# ![model_complexity.png](attachment:model_complexity.png)

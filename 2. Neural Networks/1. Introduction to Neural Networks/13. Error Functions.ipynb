# %% [markdown]
# # Error Function
#
# The error function is how far we are (ANN) to be accurate to the prediction
# The error is telling us how badly we are predicting
#
# [Hello Gradient Descent](https://medium.com/ai-society/hello-gradient-descent-ef74434bdfa5)
#
# ## Implementing Gradient Descent
#
# The prediction is the answer we get from the algorithm:
# - Discrete answer: Yes / No
# - Continous answer: 63.7%
#
# ![continous_discrete.png](attachment:continous_discrete.png)

# %% [markdown]
# ## Continous Function
#
# To predict continous predictions, we are going to use the Sigmoid function
#
# [Activation Functions](https://towardsdatascience.com/activation-functions-neural-networks-1cbd9f8d91d6)

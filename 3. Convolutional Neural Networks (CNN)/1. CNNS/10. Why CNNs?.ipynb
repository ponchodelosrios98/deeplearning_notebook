# %% [markdown]
# # Convolutional Neural Networks
#
# Can see an image as a whole, this helps find patterns in more complicated environments.
#
# Analyzes group of images at a time instead of splitting the data into a big matrix
#
# ![layer_example.png](attachment:layer_example.png)
#
# ![splitted_regions.png](attachment:splitted_regions.png)
#
# Take as example this input, the CNN will find patterns that make the number 6
#
# ![six.png](attachment:six.png)
